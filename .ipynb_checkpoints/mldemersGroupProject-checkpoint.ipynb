# %% [markdown]
# # Group Project Mikayla Demers

# %% [markdown]
# ### URL: https://en.wikipedia.org/wiki/List_of_best-selling_music_artists

# %%
import urllib.request
url = "https://en.wikipedia.org/wiki/List_of_best-selling_music_artists"
page = urllib.request.urlopen(url)
from bs4 import BeautifulSoup, NavigableString
soup = BeautifulSoup(page, "lxml")

# %%
#print(soup.prettify())

# %%
soup.title
# Out:
# <title>List of best-selling music artists - Wikipedia</title>

# %%
for row in artist_table.findAll('tr'):
    artist=row.findAll('th')[0].find(text=True)
    cells=row.findAll('td')
    if len(cells)==0:
        continue
        
    print(len(cells))
    print(artist)

    for i, column in enumerate(cells):
        print(i, column.find(text=True))
    break
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-0044547ea949> in <module>
# ----> 1 for row in artist_table.findAll('tr'):
#       2     artist=row.findAll('th')[0].find(text=True)
#       3     cells=row.findAll('td')
#       4     if len(cells)==0:
#       5         continue
#
# NameError: name 'artist_table' is not defined

# %%
artist_table = soup.find('table',class_='wikitable plainrowheaders sortable')
artist_table.prettify()
# Out:
# '<table class="wikitable plainrowheaders sortable">\n <tbody>\n  <tr>\n   <th scope="col" style="width:130px;">\n    Artist\n   </th>\n   <th scope="col" style="width:122px;">\n    Country / Market\n   </th>\n   <th scope="col" style="width:122px;">\n    Period active\n   </th>\n   <th scope="col" style="width:122px;">\n    Release year of first charted record\n   </th>\n   <th scope="col" style="width:122px;">\n    Genre\n   </th>\n   <th scope="col" style="width:325px;">\n    <a class="mw-redirect" href="/wiki/Music_recording_sales_certification" title="Music recording sales certification">\n     Total certified units\n    </a>\n    <br/>\n    <small>\n     (\n     <a href="/wiki/List_of_music_recording_certifications" title="List of music recording certifications">\n      from available markets\n     </a>\n     )\n    </small>\n    <sup class="reference" id="cite_ref-cert_1-1">\n     <a href="#cite_note-cert-1">\n      [a]\n     </a>\n    </sup>\n   </th>\n   <th scope="col" style="width:130px;">\n    Claimed sales\n   </th>\n  </tr>\n  <tr>\n   <th scope="row">\n    <a href="/wiki/The_Beatles" title="The Beatles">\n     The Beatles\n    </a>\n   </th>\n   <td>\n    United Kingdom\n   </td>\n   <td>\n    1960–1970\n    <sup class="reference" id="cite_ref-Allmusic:_The_Beatles_(Biography)_13-0">\n     <a href="#cite_note-Allmusic:_The_Beatles_(Biography)-13">\n      [10]\n     </a>\n    </sup>\n   </td>\n   <td>\n    1962\n    <sup class="reference" id="cite_ref-Allmusic:_The_Beatles_(Biography)_13-1">\n     <a href="#cite_note-Allmusic:_The_Beatles_(Biography)-13">\n      [10]\n     </a>\n    </sup>\n   </td>\n   <td>\n    <a href="/wiki/Rock_music" title="Rock music">\n     Rock\n    </a>\n    /\n    <a href="/wiki/Pop_music" title="Pop music">\n     Pop\n    </a>\n    <sup class="reference" id="cite_ref-Allmusic:_The_Beatles_(Biography)_13-2">\n     <a href="#cite_note-Allmusic:_The_Beatles_(Biography)-13">\n      [10]\n     </a>\n    </sup>\n   </td>\n   <td>\n    <small>\n     <span data-sort-value="7002283600000000000♠" style="display:none">\n     </span>\n     <div class="mw-collapsible mw-collapsed" style="box-sizing:border-box;width:100%;font-size:95%;padding:4px;border:none;">\n      <div style="font-size:100%;line-height:1.6;font-weight:bold;background:transparent;text-align:center;;">\n       <br/>\n       <b>\n        Total available certified units: 283.6 million\n       </b>\n      </div>\n      <div class="mw-collapsible-content" style="background:transparent;text-align:left;;">\n       <ul>\n        <li>\n         <a href="/wiki/Recording_Industry_Association_of_America" title="Recording Industry Association of America">\n          US\n         </a>\n         : 217.250 million\n         <sup class="reference" id="cite_ref-RIAA_Certifications_14-0">\n          <a href="#cite_note-RIAA_Certifications-14">\n           [11]\n          </a>\n         </sup>\n        </li>\n        <li>\n         <a href="/wiki/Recording_Industry_Association_of_Japan" title="Recording Industry Association of Japan">\n          JPN\n         </a>\n         : 4.950 million\n         <sup class="reference" id="cite_ref-cert_1-2">\n          <a href="#cite_note-cert-1">\n           [a]\n          </a>\n         </sup>\n         <sup class="reference" id="cite_ref-RIAJ_certifications_15-0">\n          <a href="#cite_note-RIAJ_certifications-15">\n           [12]\n          </a>\n         </sup>\n        </li>\n        <li>\n         <a href="/wiki/Bundesverband_Musikindustrie" title="Bundesverband Musikindustrie">\n          GER\n         </a>\n         : 8 million\n         <sup class="reference" id="cite_ref-cert_1-3">\n          <a href="#cite_note-cert-1">\n           [a]\n          </a>\n         </sup>\n         <sup class="reference" id="cite_ref-BVMI_Certifications_16-0">\n          <a href="#cite_note-BVMI_Certifications-16">\n           [13]\n          </a>\n         </sup>\n        </li>\n        <li>\n         <a href="/wik ...

# %%
A=[]
B=[]
C=[]
D=[]
E=[]
F=[]
G=[]

for row in artist_table.findAll('tr'):
    g1 = ''
    g2 = ''
    artist=row.findAll('th')[0].find(text=True)

    cells=row.findAll('td')
    if len(cells)==6:
        for g in cells[3]:
            if isinstance(g, NavigableString) or g.name == "a":
                 g1 += g.string.strip()
                
        A.append(artist)
        B.append(cells[0].find(text=True).rstrip())
        C.append(cells[1].find(text=True))
        D.append(cells[2].find(text=True))
        E.append(g1)
        F.append(cells[4].findAll('b')[0].find(text=True))
        G.append(cells[5].find(text=True))

# %%
import pandas as pd
df=pd.DataFrame(A,columns=['Artist'])
df['Country / Market']=B
df['Period active']=C
df['Release year of first charted record']=D
df['Genre']=E
df['Total certified units (from available markets)']=F
df['Claimed sales']=G
df
# Out:
#             Artist Country / Market               Period active  \
# 0      The Beatles   United Kingdom                   1960–1970
# 1    Elvis Presley    United States                   1954–1977
# 2  Michael Jackson    United States                   1964–2009
# 3       Elton John   United Kingdom                1964–present
# 4          Madonna    United States                1979–present
# 5     Led Zeppelin   United Kingdom                   1968–1980
# 6          Rihanna         Barbados                2005–present
# 7       Pink Floyd   United Kingdom  1965–1996, 2005, 2012–2014
#
#   Release year of first charted record                              Genre  \
# 0                                 1962                           Rock/Pop
# 1                                 1954        Rock and roll/ Pop /Country
# 2                                 1971     Pop / Rock / Dance / Soul /R&B
# 3                                 1969                         Pop / Rock
# 4                                 1982           Pop / Dance /Electronica
# 5                                 1969    Hard rock /Blues rock/Folk rock
# 6                                 2005        R&B / Pop / Dance / Hip-hop
# 7                                 1967  Progressive rock/Psychedelic rock
#
#    Total certified units (from available markets) Claimed sales
# 0  Total available certified units: 283.4 million   600 million
# 1  Total available certified units: 227.7 million   600 million
# 2  Total available certified units: 236.8 million   350 million
# 3  Total available certified units: 194.9 million   300 million
# 4  Total available certified units: 178.9 million   300 million
# 5    Total available certified units: 141 million   300 million
# 6  Total available certified units: 300.1 million   250 million
# 7  Total available certified units: 121.4 million   250 million

# %%
df.to_csv('CSC221_webscrape_data.csv')

# %%
from matplotlib import pyplot as plt

# %%
plt.figure(figsize = (15,10))
plt.bar(range(0,len(a["Claimed sales"])), a["Total certified units (from available markets)"], label = "Total certified units (from available markets)", linewidth = 5, color = "red")
plt.plot(a["Claimed sales"],label = "Claimed sales", linestyle = "-." )
plt.xticks(range(0,len(a["Claimed sales"])), a["Release year of first charted record"], rotation = 90)
plt.legend(loc = "upper right", fontsize = 14)
plt.xlabel("Release year of first charted record")
plt.show()
